# %% [markdown]
# # Mini Project - Card Game

# %% [markdown]
# ### It is a very common game named Patte pe Patta

# %%
#For this we need to build for classes
#1 . Card class - Hold the information about the card
#2 . Deck class - Hold the information baout the complete set of 52 cards
#3 . Player class - Hold the information about the cards the player are having
#4 . Table class - Holds the information about the cards on table.\

# %%
#First we need to include the global variables and  random module

# %% [markdown]
# ## Rules of the game

# %%
'''
1. This game involves two players and initialy each player is given 26 cards each.
2. They have to put there top card on the table turn wise
3. If the card they are going to put on table matchs with the already top card on the table
MATCH condition - Two cards match if they have same suit OR if they have same rank
4. Player wins that chance and he take all the cards on the table and add all those cards to the end of the deck of cards he
already have.
5. This way game runs until one of the player run out of cards
6. The player that run out of cards losses and other player wins the game!!!!!
'''

# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

# %% [markdown]
# ### Card class

# %%
#this class has the information about the a particular card
class Card:

    def __init__(self,suit,rank):
        self.suit = suit           # identity of a card
        self.rank = rank
        
    def __str__(self):
        return self.rank + ' of ' + self.suit     #returns a string defining the card

# %% [markdown]
# ### Deck class

# %%
#this class contains the set of 52 cards and each card the obeject of previously defined class card.
class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))  # build Card objects and add them to the list
    
    def __str__(self):
        deck_comp = ''  # start with an empty string
        for card in self.deck:
            deck_comp += '\n '+card.__str__() # add each Card object's print string
        return 'The deck has:' + deck_comp

    def shuffle(self):           # Shuffles the 52 cards
        random.shuffle(self.deck)          
    def __len__(self):
        return len(self.deck)

# %% [markdown]
# ### Player class

# %%
# Player class has all the information about the cards a player is holding
class Player:
    def __init__(self,name):
        self.cards = []
        self.name = name
    def add(self , new_cards):          # Add the cards from the table after the persor wins
        self.cards.extend(new_cards)  
        
    def move(self):                     #Puts one card on the table
        return self.cards.pop(0)
    
    def __str__(self):
        ans =''
        for cards in self.cards:
            ans += '\n' + cards.__str__()
        return  self.name +" has the following cards:" +ans
    def __len__(self):
        return len(self.cards)

# %% [markdown]
# ### Table class

# %%
# this class has the information about all the cards on the table
class Table:
    def __init__(self):
        self.cards = []
    
    def add(self , new_cards):                     #Adds the new card to the table as the player moves 
        self.cards.append(new_cards)
        
    def remove(self):                                #All the cards are removed and given to a particular person
        self.cards = []
    
    def __str__(self):
        ans = ''
        for cards in self.cards:
            ans += '\n' + cards.__str__()
        return "Table has the following cards:" + ans
    def __len__(self):
        return len(self.cards)

# %%
# This function takes the input names of the players
def player_name():   
    user_1 = input("Hi! Please enter name of first player")  #stores the name of first user
    print("Hi" , user_1)
    user_2 = input("Hi! Please enter name of second player") #stores the name of second user
    print("Hi" ,user_2)
    return(user_1 ,user_2 )

# %%
#Initializing a deck
deck = Deck()
deck.shuffle()
len(deck)
# Out:
# 52

# %%
#make new players
name_1 , name_2 = player_name()
user_1 = Player(name_1)
user_2 = Player(name_2)
# Out:
# Hi! Please enter name of first playerArpit
# Hi Arpit
# Hi! Please enter name of second playerAmit
# Hi Amit

# %%
#Add initial cards
user_1.add(deck.deck[0:26])
user_2.add(deck.deck[26:52])

# %%
print(user_1)
# Out:
# Arpit has the following cards:
# Two of Clubs
# Five of Spades
# Two of Hearts
# Jack of Diamonds
# Eight of Hearts
# Queen of Diamonds
# Seven of Hearts
# Six of Clubs
# Four of Hearts
# King of Diamonds
# Two of Spades
# Nine of Diamonds
# Four of Diamonds
# Three of Spades
# Six of Spades
# Nine of Clubs
# Queen of Clubs
# Ace of Hearts
# Queen of Hearts
# Three of Diamonds
# Five of Diamonds
# Queen of Spades
# Seven of Spades
# Eight of Diamonds
# Ace of Clubs
# Eight of Clubs

# %%
print(user_2)
# Out:
# Amit has the following cards:
# Eight of Spades
# Three of Hearts
# Jack of Hearts
# Five of Hearts
# King of Spades
# Jack of Spades
# Ten of Spades
# Four of Spades
# Ten of Hearts
# Seven of Clubs
# Jack of Clubs
# Five of Clubs
# Ten of Diamonds
# Four of Clubs
# Two of Diamonds
# King of Clubs
# Six of Diamonds
# Nine of Spades
# Three of Clubs
# Seven of Diamonds
# Ace of Spades
# Nine of Hearts
# King of Hearts
# Six of Hearts
# Ten of Clubs
# Ace of Diamonds

# %%
# Intitalizing the new table for our game.
table = Table()

# %%
player =1
while(True):
    print("No of cards with",user_1.name,"are",len(user_1))
    print("No of cards with",user_2.name,"are",len(user_2))
    print("No of cards on table are",len(table))
    print('\n')
    if player == 1:
        card = user_1.move()
        print(user_1.name,"Please press enter to move a chance. You have a",card.__str__() ,'\n')
        a = input("Press any key")
        print("Top Cards on table are",'\n')
        table.add(card)
        print(table.cards[-1])
        if len(table) > 1:
            print(table.cards[-2])
        if len(table) > 1:
            if table.cards[-1].suit == table.cards[-2].suit or table.cards[-1].rank == table.cards[-2].rank:
                print("Woohho Top two cards match" , user_1.name, "Wins this move",'\n')
                user_1.add(table.cards[::-1])
                table.remove()
        player = 2
    else :
        card = user_2.move()
        print(user_2.name,"Please press enter to move a chance. You have a",card.__str__(),'\n')
        a = input("Press any key")
        print("Top Cards on table are",'\n')
        table.add(card)
        print(table.cards[-1])
        if len(table) > 1:
            print(table.cards[-2])
        if len(table) > 1:
            if table.cards[-1].suit == table.cards[-2].suit or table.cards[-1].rank == table.cards[-2].rank:
                print("Woohho Top two cards match" , user_2.name, "Wins this move",'\n')
                user_2.add(table.cards[::-1])
                table.remove()
        player = 1
        
    print('\n')
    if len(user_1) == 0:
        print("Congrats",user_2.name,"Won")
        break
    if len(user_2) == 0:
        print("Congrats",user_1.name,"Won")
        break
# Out:
# No of cards with Arpit are 26
# No of cards with Amit are 26
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 26
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Two of Clubs
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 25
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Five of Spades
#
# Press any key
# Top Cards on table are
#
# Five of Spades
# Eight of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 25
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
#
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 24
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
# Three of Hearts
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 28
# No of cards with Amit are 24
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
#
#
#
#
# No of cards with Arpit are 28
# No of cards with Amit are 23
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
# Jack of Hearts
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 29
# No of cards with Amit are 23
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
#
#
#
#
# No of cards with Arpit are 29
# No of cards with Amit are 22
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# Five of Hearts
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 30
# No of cards with Amit are 22
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
#
#
#
#
# No of cards with Arpit are 30
# No of cards with Amit are 21
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# King of Spades
#
#
#
#
# No of cards with Arpit are 29
# No of cards with Amit are 21
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
# Queen of Diamonds
#
#
#
#
# No of cards with Arpit are 29
# No of cards with Amit are 20
# No of cards on table are 3
#
#
# Arpit Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
# Jack of Spades
#
#
#
#
# No of cards with Arpit are 28
# No of cards with Amit are 20
# No of cards on table are 4
#
#
# Amit Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
# Seven of Hearts
#
#
#
#
# No of cards with Arpit are 28
# No of cards with Amit are 19
# No of cards on table are 5
#
#
# Arpit Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Ten of Spades
#
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 19
# No of cards on table are 6
#
#
# Amit Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
# Six of Clubs
#
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 18
# No of cards on table are 7
#
#
# Arpit Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
# Four of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 34
# No of cards with Amit are 18
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Ten of Hearts
#
# Press any key
# Top Cards on table are
#
# Ten of Hearts
#
#
#
#
# No of cards with Arpit are 34
# No of cards with Amit are 17
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a King of Diamonds
#
# Press any key
# Top Cards on table are
#
# King of Diamonds
# Ten of Hearts
#
#
#
#
# No of cards with Arpit are 33
# No of cards with Amit are 17
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
# King of Diamonds
#
#
#
#
# No of cards with Arpit are 33
# No of cards with Amit are 16
# No of cards on table are 3
#
#
# Arpit Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
# Seven of Clubs
#
#
#
#
# No of cards with Arpit are 32
# No of cards with Amit are 16
# No of cards on table are 4
#
#
# Amit Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
# Two of Spades
#
#
#
#
# No of cards with Arpit are 32
# No of cards with Amit are 15
# No of cards on table are 5
#
#
# Arpit Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
# Jack of Clubs
#
#
#
#
# No of cards with Arpit are 31
# No of cards with Amit are 15
# No of cards on table are 6
#
#
# Amit Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Nine of Diamonds
#
#
#
#
# No of cards with Arpit are 31
# No of cards with Amit are 14
# No of cards on table are 7
#
#
# Arpit Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Five of Clubs
#
#
#
#
# No of cards with Arpit are 30
# No of cards with Amit are 14
# No of cards on table are 8
#
#
# Amit Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
# Four of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 30
# No of cards with Amit are 22
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Three of Spades
#
# Press any key
# Top Cards on table are
#
# Three of Spades
#
#
#
#
# No of cards with Arpit are 29
# No of cards with Amit are 22
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Three of Spades
#
#
#
#
# No of cards with Arpit are 29
# No of cards with Amit are 21
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Four of Clubs
#
#
#
#
# No of cards with Arpit are 28
# No of cards with Amit are 21
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Six of Spades
#
#
#
#
# No of cards with Arpit are 28
# No of cards with Amit are 20
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Two of Diamonds
#
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 20
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a King of Clubs
#
# Press any key
# Top Cards on table are
#
# King of Clubs
# Nine of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 25
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 25
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
# Queen of Clubs
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 24
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Ace of Hearts
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# Six of Diamonds
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 24
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Nine of Spades
#
# Press any key
# Top Cards on table are
#
# Nine of Spades
# Ace of Hearts
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 23
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
# Nine of Spades
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 23
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# Queen of Hearts
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 22
# No of cards on table are 6
#
#
# Arpit Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
# Three of Clubs
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 30
# No of cards with Amit are 22
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
#
#
#
#
# No of cards with Arpit are 30
# No of cards with Amit are 21
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Seven of Diamonds
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 31
# No of cards with Amit are 21
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Ace of Spades
#
# Press any key
# Top Cards on table are
#
# Ace of Spades
#
#
#
#
# No of cards with Arpit are 31
# No of cards with Amit are 20
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# Ace of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 32
# No of cards with Amit are 20
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
#
#
#
#
# No of cards with Arpit are 32
# No of cards with Amit are 19
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Seven of Spades
#
# Press any key
# Top Cards on table are
#
# Seven of Spades
# Nine of Hearts
#
#
#
#
# No of cards with Arpit are 31
# No of cards with Amit are 19
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
# Seven of Spades
#
#
#
#
# No of cards with Arpit are 31
# No of cards with Amit are 18
# No of cards on table are 3
#
#
# Arpit Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
# King of Hearts
#
#
#
#
# No of cards with Arpit are 30
# No of cards with Amit are 18
# No of cards on table are 4
#
#
# Amit Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Eight of Diamonds
#
#
#
#
# No of cards with Arpit are 30
# No of cards with Amit are 17
# No of cards on table are 5
#
#
# Arpit Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# Six of Hearts
#
#
#
#
# No of cards with Arpit are 29
# No of cards with Amit are 17
# No of cards on table are 6
#
#
# Amit Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
# Ace of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 29
# No of cards with Amit are 23
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
#
#
#
#
# No of cards with Arpit are 28
# No of cards with Amit are 23
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ace of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ace of Diamonds
# Eight of Clubs
#
#
#
#
# No of cards with Arpit are 28
# No of cards with Amit are 22
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Five of Spades
#
# Press any key
# Top Cards on table are
#
# Five of Spades
# Ace of Diamonds
#
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 22
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
# Five of Spades
#
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 21
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Ten of Diamonds
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 21
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Eight of Spades
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 20
# No of cards on table are 6
#
#
# Arpit Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
# Four of Diamonds
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 20
# No of cards on table are 7
#
#
# Amit Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Two of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 27
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 27
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
# Two of Hearts
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 26
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
# Nine of Diamonds
#
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 26
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
# Three of Hearts
#
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 25
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
# Jack of Clubs
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 25
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
#
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 24
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
# Two of Spades
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 24
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
# Jack of Hearts
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 23
# No of cards on table are 3
#
#
# Arpit Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# Seven of Clubs
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 23
# No of cards on table are 4
#
#
# Amit Please press enter to move a chance. You have a King of Diamonds
#
# Press any key
# Top Cards on table are
#
# King of Diamonds
# Eight of Hearts
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 22
# No of cards on table are 5
#
#
# Arpit Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
# King of Diamonds
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 22
# No of cards on table are 6
#
#
# Amit Please press enter to move a chance. You have a Ten of Hearts
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Five of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 28
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
#
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 28
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a King of Clubs
#
# Press any key
# Top Cards on table are
#
# King of Clubs
# Four of Hearts
#
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 27
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
# King of Clubs
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 27
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Four of Spades
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 26
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Nine of Clubs
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 26
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 25
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
# Two of Diamonds
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 25
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Ten of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 27
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 27
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Seven of Hearts
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 26
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
# Four of Clubs
#
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 26
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Three of Spades
#
# Press any key
# Top Cards on table are
#
# Three of Spades
# Jack of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 29
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 29
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
# Queen of Diamonds
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 28
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
# Ten of Clubs
#
#
#
#
# No of cards with Arpit are 21
# No of cards with Amit are 28
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# King of Spades
#
#
#
#
# No of cards with Arpit are 21
# No of cards with Amit are 27
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
# Ace of Clubs
#
#
#
#
# No of cards with Arpit are 20
# No of cards with Amit are 27
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Three of Diamonds
#
#
#
#
# No of cards with Arpit are 20
# No of cards with Amit are 26
# No of cards on table are 6
#
#
# Arpit Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# Six of Hearts
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 26
# No of cards on table are 7
#
#
# Amit Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
# Three of Clubs
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 25
# No of cards on table are 8
#
#
# Arpit Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
# Eight of Diamonds
#
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 25
# No of cards on table are 9
#
#
# Amit Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
# Queen of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 34
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Nine of Spades
#
# Press any key
# Top Cards on table are
#
# Nine of Spades
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 34
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Seven of Spades
#
# Press any key
# Top Cards on table are
#
# Seven of Spades
# Nine of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 35
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
#
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 35
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
# Ace of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 36
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 36
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Six of Diamonds
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 35
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
# Five of Clubs
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 35
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 34
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Two of Clubs
#
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 34
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Five of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 36
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 36
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Eight of Spades
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Seven of Diamonds
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 35
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# Eight of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 35
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 34
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Ace of Spades
#
# Press any key
# Top Cards on table are
#
# Ace of Spades
# Ten of Diamonds
#
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 34
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Five of Spades
#
# Press any key
# Top Cards on table are
#
# Five of Spades
# Ace of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 36
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 36
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ace of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ace of Diamonds
# Jack of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 37
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 37
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
# Jack of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 38
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 38
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ten of Hearts
#
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Three of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 39
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 39
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
# Nine of Diamonds
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 38
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
# Five of Hearts
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 38
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a King of Diamonds
#
# Press any key
# Top Cards on table are
#
# King of Diamonds
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 37
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# King of Diamonds
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 37
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# Six of Clubs
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 36
# No of cards on table are 3
#
#
# Arpit Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Eight of Hearts
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 36
# No of cards on table are 4
#
#
# Amit Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
# Nine of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 40
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 40
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
# Four of Spades
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 39
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a King of Clubs
#
# Press any key
# Top Cards on table are
#
# King of Clubs
# Jack of Hearts
#
#
#
#
# No of cards with Arpit are 10
# No of cards with Amit are 39
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
# King of Clubs
#
#
#
#
# No of cards with Arpit are 10
# No of cards with Amit are 38
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
# Two of Spades
#
#
#
#
# No of cards with Arpit are 9
# No of cards with Amit are 38
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Four of Hearts
#
#
#
#
# No of cards with Arpit are 9
# No of cards with Amit are 37
# No of cards on table are 6
#
#
# Arpit Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
# Six of Spades
#
#
#
#
# No of cards with Arpit are 8
# No of cards with Amit are 37
# No of cards on table are 7
#
#
# Amit Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
# Queen of Clubs
#
#
#
#
# No of cards with Arpit are 8
# No of cards with Amit are 36
# No of cards on table are 8
#
#
# Arpit Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Ten of Spades
#
#
#
#
# No of cards with Arpit are 7
# No of cards with Amit are 36
# No of cards on table are 9
#
#
# Amit Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Five of Clubs
#
#
#
#
# No of cards with Arpit are 7
# No of cards with Amit are 35
# No of cards on table are 10
#
#
# Arpit Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
# Two of Diamonds
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 35
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Three of Spades
#
# Press any key
# Top Cards on table are
#
# Three of Spades
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 34
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# Three of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 34
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
#
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 33
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Jack of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 33
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Four of Clubs
# Press any key
# Top Cards on table are
#
# Four of Clubs
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 32
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Four of Clubs
#
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 32
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
# Seven of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 34
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 34
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
# Two of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 35
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
#
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 35
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
# Five of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 36
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 36
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
# Nine of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 37
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 37
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# Six of Diamonds
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 36
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Three of Clubs
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 36
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Two of Diamonds
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 35
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Six of Hearts
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 35
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
# Five of Clubs
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 34
# No of cards on table are 6
#
#
# Arpit Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
# Three of Diamonds
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 34
# No of cards on table are 7
#
#
# Amit Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# Ten of Spades
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 33
# No of cards on table are 8
#
#
# Arpit Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
# Ace of Clubs
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 33
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 32
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# King of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 20
# No of cards with Amit are 32
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
#
#
#
#
# No of cards with Arpit are 20
# No of cards with Amit are 31
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
# Ten of Clubs
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 31
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# Four of Hearts
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 30
# No of cards on table are 3
#
#
# Arpit Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
# Queen of Diamonds
#
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 30
# No of cards on table are 4
#
#
# Amit Please press enter to move a chance. You have a Seven of Spades
#
# Press any key
# Top Cards on table are
#
# Seven of Spades
# Two of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 34
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a King of Clubs
#
# Press any key
# Top Cards on table are
#
# King of Clubs
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 34
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Nine of Spades
#
# Press any key
# Top Cards on table are
#
# Nine of Spades
# King of Clubs
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 33
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
# Nine of Spades
#
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 33
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
# Jack of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 36
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 36
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# Four of Spades
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 35
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# Ace of Hearts
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 35
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Queen of Spades
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 34
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Three of Spades
#
# Press any key
# Top Cards on table are
#
# Three of Spades
# Four of Diamonds
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 34
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Three of Spades
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 33
# No of cards on table are 6
#
#
# Arpit Please press enter to move a chance. You have a Eight of Spades
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Five of Diamonds
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 33
# No of cards on table are 7
#
#
# Amit Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
# Eight of Spades
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 32
# No of cards on table are 8
#
#
# Arpit Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
# Two of Clubs
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 32
# No of cards on table are 9
#
#
# Amit Please press enter to move a chance. You have a Five of Spades
#
# Press any key
# Top Cards on table are
#
# Five of Spades
# Jack of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 41
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
#
#
#
#
# No of cards with Arpit are 10
# No of cards with Amit are 41
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ace of Spades
#
# Press any key
# Top Cards on table are
#
# Ace of Spades
# Queen of Clubs
#
#
#
#
# No of cards with Arpit are 10
# No of cards with Amit are 40
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# Ace of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 40
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 39
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
# Ten of Diamonds
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 39
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Ace of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ace of Diamonds
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 38
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
# Ace of Diamonds
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 38
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 37
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Jack of Diamonds
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 37
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
# Five of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 39
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 39
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
# Six of Hearts
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 38
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Jack of Clubs
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 38
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Ten of Hearts
#
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Two of Diamonds
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 37
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# Ten of Hearts
#
#
#
#
# No of cards with Arpit are 10
# No of cards with Amit are 37
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
# Three of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 10
# No of cards with Amit are 42
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
#
#
#
#
# No of cards with Arpit are 9
# No of cards with Amit are 42
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
# Six of Diamonds
#
#
#
#
# No of cards with Arpit are 9
# No of cards with Amit are 41
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Seven of Clubs
#
#
#
#
# No of cards with Arpit are 8
# No of cards with Amit are 41
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Six of Spades
#
#
#
#
# No of cards with Arpit are 8
# No of cards with Amit are 40
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
# Nine of Clubs
#
#
#
#
# No of cards with Arpit are 7
# No of cards with Amit are 40
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# King of Spades
#
#
#
#
# No of cards with Arpit are 7
# No of cards with Amit are 39
# No of cards on table are 6
#
#
# Arpit Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# Eight of Hearts
#
#
#
#
# No of cards with Arpit are 6
# No of cards with Amit are 39
# No of cards on table are 7
#
#
# Amit Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Ace of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# ...
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
# Five of Spades
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 26
# No of cards on table are 4
#
#
# Amit Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
# Eight of Diamonds
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 25
# No of cards on table are 5
#
#
# Arpit Please press enter to move a chance. You have a Ten of Spades
# Press any key
# Top Cards on table are
#
# Ten of Spades
# Jack of Spades
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 25
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
#
#
#
#
# No of cards with Arpit are 27
# No of cards with Amit are 24
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
# Two of Clubs
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 24
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Five of Hearts
#
#
#
#
# No of cards with Arpit are 26
# No of cards with Amit are 23
# No of cards on table are 3
#
#
# Arpit Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Eight of Spades
#
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 23
# No of cards on table are 4
#
#
# Amit Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Seven of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 25
# No of cards with Amit are 27
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 27
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Three of Spades
#
# Press any key
# Top Cards on table are
#
# Three of Spades
# Queen of Hearts
#
#
#
#
# No of cards with Arpit are 24
# No of cards with Amit are 26
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
# Three of Spades
#
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 26
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Ten of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 29
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 29
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# Two of Hearts
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 28
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Ace of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ace of Diamonds
# Queen of Spades
#
#
#
#
# No of cards with Arpit are 21
# No of cards with Amit are 28
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# Ace of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 21
# No of cards with Amit are 31
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
#
#
#
#
# No of cards with Arpit are 20
# No of cards with Amit are 31
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
# King of Hearts
#
#
#
#
# No of cards with Arpit are 20
# No of cards with Amit are 30
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
# Four of Spades
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 30
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
# Three of Diamonds
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 29
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Eight of Clubs
#
#
# Woohho Top two cards match Arpit Wins this move
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 29
# No of cards on table are 0
#
#
# Amit Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
#
#
#
#
# No of cards with Arpit are 23
# No of cards with Amit are 28
# No of cards on table are 1
#
#
# Arpit Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
# Five of Clubs
#
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 28
# No of cards on table are 2
#
#
# Amit Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
# Nine of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 22
# No of cards with Amit are 30
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Nine of Spades
#
# Press any key
# Top Cards on table are
#
# Nine of Spades
#
#
#
#
# No of cards with Arpit are 21
# No of cards with Amit are 30
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
# Nine of Spades
#
#
#
#
# No of cards with Arpit are 21
# No of cards with Amit are 29
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
# Three of Hearts
#
#
#
#
# No of cards with Arpit are 20
# No of cards with Amit are 29
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# Queen of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 20
# No of cards with Amit are 32
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
#
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 32
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ten of Hearts
#
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Jack of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 19
# No of cards with Amit are 33
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Seven of Spades
#
# Press any key
# Top Cards on table are
#
# Seven of Spades
#
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 33
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Seven of Spades
#
#
#
#
# No of cards with Arpit are 18
# No of cards with Amit are 32
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
# Two of Diamonds
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 32
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
# Nine of Hearts
#
#
#
#
# No of cards with Arpit are 17
# No of cards with Amit are 31
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a King of Diamonds
#
# Press any key
# Top Cards on table are
#
# King of Diamonds
# Jack of Clubs
#
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 31
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# King of Diamonds
#
#
#
#
# No of cards with Arpit are 16
# No of cards with Amit are 30
# No of cards on table are 6
#
#
# Arpit Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
# Six of Hearts
#
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 30
# No of cards on table are 7
#
#
# Amit Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Ten of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 15
# No of cards with Amit are 37
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 37
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# Two of Spades
#
#
#
#
# No of cards with Arpit are 14
# No of cards with Amit are 36
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
# Ace of Clubs
#
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 36
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# Four of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 13
# No of cards with Amit are 39
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Ace of Spades
#
# Press any key
# Top Cards on table are
#
# Ace of Spades
#
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 39
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
# Ace of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 12
# No of cards with Amit are 40
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 40
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Queen of Diamonds
#
#
#
#
# No of cards with Arpit are 11
# No of cards with Amit are 39
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
# Nine of Clubs
#
#
#
#
# No of cards with Arpit are 10
# No of cards with Amit are 39
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Ten of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 10
# No of cards with Amit are 42
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
#
#
#
#
# No of cards with Arpit are 9
# No of cards with Amit are 42
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
# Jack of Spades
#
#
#
#
# No of cards with Arpit are 9
# No of cards with Amit are 41
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
# Seven of Clubs
#
#
#
#
# No of cards with Arpit are 8
# No of cards with Amit are 41
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
# Eight of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 8
# No of cards with Amit are 44
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Five of Spades
#
# Press any key
# Top Cards on table are
#
# Five of Spades
#
#
#
#
# No of cards with Arpit are 7
# No of cards with Amit are 44
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Five of Spades
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 7
# No of cards with Amit are 45
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
#
#
#
#
# No of cards with Arpit are 6
# No of cards with Amit are 45
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Seven of Hearts
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 6
# No of cards with Amit are 46
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a King of Clubs
#
# Press any key
# Top Cards on table are
#
# King of Clubs
#
#
#
#
# No of cards with Arpit are 5
# No of cards with Amit are 46
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# King of Clubs
#
#
#
#
# No of cards with Arpit are 5
# No of cards with Amit are 45
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Eight of Spades
#
#
#
#
# No of cards with Arpit are 4
# No of cards with Amit are 45
# No of cards on table are 3
#
#
# Amit Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
# Four of Clubs
#
#
#
#
# No of cards with Arpit are 4
# No of cards with Amit are 44
# No of cards on table are 4
#
#
# Arpit Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
# Five of Hearts
#
#
#
#
# No of cards with Arpit are 3
# No of cards with Amit are 44
# No of cards on table are 5
#
#
# Amit Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
# Eight of Clubs
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 3
# No of cards with Amit are 49
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
#
#
#
#
# No of cards with Arpit are 2
# No of cards with Amit are 49
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Three of Diamonds
#
#
# Woohho Top two cards match Amit Wins this move
#
#
#
# No of cards with Arpit are 2
# No of cards with Amit are 50
# No of cards on table are 0
#
#
# Arpit Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
#
#
#
#
# No of cards with Arpit are 1
# No of cards with Amit are 50
# No of cards on table are 1
#
#
# Amit Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
# Four of Spades
#
#
#
#
# No of cards with Arpit are 1
# No of cards with Amit are 49
# No of cards on table are 2
#
#
# Arpit Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
# Ten of Diamonds
#
#
#
#
# Congrats Amit Won

# %%
# Out:
# [4, 3, 2, 1]
